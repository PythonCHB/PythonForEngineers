# 18    Harlingen    94.0          NaN                    NaN      cm
# 19    Harlingen    95.0          NaN                    NaN      cm
# 20    Harlingen    97.0          NaN                    NaN      cm
# 21    Harlingen   102.0          NaN                    NaN      cm
# 22    Harlingen   101.0          NaN                    NaN      cm
# 23    Harlingen    98.0          NaN                    NaN      cm
# 24    Harlingen   101.0          NaN                    NaN      cm
# 25    Harlingen   104.0          NaN                    NaN      cm
# 26    Harlingen   104.0          NaN                    NaN      cm
# 27    Harlingen   105.0          NaN                    NaN      cm
# 28    Harlingen   110.0          NaN                    NaN      cm
# 29    Harlingen   109.0          NaN                    NaN      cm
# ...         ...     ...          ...                    ...     ...
# 3999  Harlingen    94.0          NaN                    NaN      cm
# 4000  Harlingen    86.0          NaN                    NaN      cm
# 4001  Harlingen    80.0          NaN                    NaN      cm
# 4002  Harlingen    77.0          NaN                    NaN      cm
# 4003  Harlingen    74.0          NaN                    NaN      cm
# 4004  Harlingen    70.0          NaN                    NaN      cm
# 4005  Harlingen    66.0          NaN                    NaN      cm
# 4006  Harlingen    61.0          NaN                    NaN      cm
# 4007  Harlingen    57.0          NaN                    NaN      cm
# 4008  Harlingen    53.0          NaN                    NaN      cm
# 4009  Harlingen    50.0          NaN                    NaN      cm
# 4010  Harlingen    46.0          NaN                    NaN      cm
# 4011  Harlingen    43.0          NaN                    NaN      cm
# 4012  Harlingen    40.0          NaN                    NaN      cm
# 4013  Harlingen    38.0          NaN                    NaN      cm
# 4014  Harlingen    35.0          NaN                    NaN      cm
# 4015  Harlingen    34.0          NaN                  -67.0      cm
# 4016  Harlingen    34.0          NaN                  -66.0      cm
# 4017  Harlingen    35.0          NaN                  -64.0      cm
# 4018  Harlingen    37.0          NaN                  -62.0      cm
# 4019  Harlingen    40.0          NaN                  -58.0      cm
# 4020  Harlingen    44.0         31.0                  -54.0      cm
# 4021  Harlingen     NaN         38.0                  -49.0      cm
# 4022  Harlingen     NaN         47.0                  -43.0      cm
# 4023  Harlingen     NaN         54.0                  -37.0      cm
# 4024  Harlingen     NaN         64.0                  -29.0      cm
# 4025  Harlingen     NaN         71.0                  -21.0      cm
# 4026  Harlingen     NaN          NaN                  -13.0      cm
# 4027  Harlingen     NaN          NaN                   -5.0      cm
# 4028  Harlingen     NaN          NaN                    4.0      cm
#
#       Bemonsteringshoogte Referentievlak  Unnamed: 10
# 0            -999999999.0            NAP          NaN
# 1            -999999999.0            NAP          NaN
# 2            -999999999.0            NAP          NaN
# 3            -999999999.0            NAP          NaN
# 4            -999999999.0            NAP          NaN
# 5            -999999999.0            NAP          NaN
# 6            -999999999.0            NAP          NaN
# 7            -999999999.0            NAP          NaN
# 8            -999999999.0            NAP          NaN
# 9            -999999999.0            NAP          NaN
# 10           -999999999.0            NAP          NaN
# 11           -999999999.0            NAP          NaN
# 12           -999999999.0            NAP          NaN
# 13           -999999999.0            NAP          NaN
# 14           -999999999.0            NAP          NaN
# 15           -999999999.0            NAP          NaN
# 16           -999999999.0            NAP          NaN
# 17           -999999999.0            NAP          NaN
# 18           -999999999.0            NAP          NaN
# 19           -999999999.0            NAP          NaN
# 20           -999999999.0            NAP          NaN
# 21           -999999999.0            NAP          NaN
# 22           -999999999.0            NAP          NaN
# 23           -999999999.0            NAP          NaN
# 24           -999999999.0            NAP          NaN
# 25           -999999999.0            NAP          NaN
# 26           -999999999.0            NAP          NaN
# 27           -999999999.0            NAP          NaN
# 28           -999999999.0            NAP          NaN
# 29           -999999999.0            NAP          NaN
# ...                   ...            ...          ...
# 3999         -999999999.0            NAP          NaN
# 4000         -999999999.0            NAP          NaN
# 4001         -999999999.0            NAP          NaN
# 4002         -999999999.0            NAP          NaN
# 4003         -999999999.0            NAP          NaN
# 4004         -999999999.0            NAP          NaN
# 4005         -999999999.0            NAP          NaN
# 4006         -999999999.0            NAP          NaN
# 4007         -999999999.0            NAP          NaN
# 4008         -999999999.0            NAP          NaN
# 4009         -999999999.0            NAP          NaN
# 4010         -999999999.0            NAP          NaN
# 4011         -999999999.0            NAP          NaN
# 4012         -999999999.0            NAP          NaN
# 4013         -999999999.0            NAP          NaN
# 4014         -999999999.0            NAP          NaN
# 4015         -999999999.0            NAP          NaN
# 4016         -999999999.0            NAP          NaN
# 4017         -999999999.0            NAP          NaN
# 4018         -999999999.0            NAP          NaN
# 4019         -999999999.0            NAP          NaN
# 4020         -999999999.0            NAP          NaN
# 4021                  NaN            NaN          NaN
# 4022                  NaN            NaN          NaN
# 4023                  NaN            NaN          NaN
# 4024                  NaN            NaN          NaN
# 4025                  NaN            NaN          NaN
# 4026                  NaN            NaN          NaN
# 4027                  NaN            NaN          NaN
# 4028                  NaN            NaN          NaN
#
# [4029 rows x 11 columns]

# %%
fig, ax = plt.subplots()
fig.set_size_inches((12,8))
X = df['Tijd']
Y = df['Meting']
ax.plot(X,Y)

# %% [markdown]
# # Hints for parsing datetimes
#
# The python datetime object has a parser called: `datetime.strptime()`. YOu can apss it a string to parse, and a format string that tells it how it is formatted. THe format codes are doumented here:
#
# https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior
#
# For this exercise, this format string should work:

# %%
dt = datetime.strptime('24-8-2018 17:50:00', "%d-%m-%Y %H:%M:%S" )
print(dt)
# Out:
# 2018-08-24 17:50:00

# %%
import csv
def read_tide_measurements(filename):
    times = []
    heights = []
    with open(filename) as infile:
        # skip the first row
        infile.readline()
        for row in csv.reader(infile, delimiter=";"):
            # fill this in here:            
            pass
    return times, heights

# %%
## Or you can take advantage of panda's csv reading:
def read_from_dataframe(filename):
    df = pd.read_csv(filename,delimiter=';')
    # the date is in the "Datum" column
    # the time is in the "Tijd" column
    # the height in in the "Meting" column
    times = []
    heights = [] 
    for row in df.itertuples():
        dt_str = row.Datum + " " + row.Tijd
        times.append(datetime.strptime(dt_str, "%d-%m-%Y %H:%M:%S"))
        heights.append(row.Meting)
    return times, heights

# %%
# T, H = read_tide_measurements("NVT_WATHTE_HARL.csv")
T, H = read_from_dataframe("NVT_WATHTE_HARL.csv")

fig, ax = plt.subplots()
fig.set_size_inches((12,8))

# ax.set_xlim((times[0], times[1000]))

ax.plot(T,H)

# %%
# Out:
# (736930.7222222222, 736931.4166666666)
